# %%
from tabula import read_pdf

# %%
from tabulate import tabulate
import pandas as pd

# %%
df  = read_pdf("Food Calories List.pdf",pages=2)
df[0]
# Out:
#     Rice (white boiled)    420 cals (300g)  140 cals  Unnamed: 0  \
# 0                   NaN                NaN       NaN         NaN
# 1      Rice (egg-fried)           500 cals  200 cals         NaN
# 2        Rice ( Brown )    405 cals (300g)  135 cals         NaN
# 3            Rice cakes  28 Cals = 1 slice  373 Cals         NaN
# 4    Ryvita Multi grain  37 Cals per slice  331 Cals         NaN
# 5  Ryvita + seed & Oats  180 Cals 4 slices  362 Cals         NaN
# 6    Spaghetti (boiled)    303 cals (300g)  101 cals         NaN
#
#        Low calorie
# 0              NaN
# 1  High in portion
# 2      Low calorie
# 3           Medium
# 4           Medium
# 5           Medium
# 6      Low calorie

# %%
df[1]
# Out:
#                Unnamed: 0            Unnamed: 1 Unnamed: 2 per 100 grams  \
# 0                     NaN          Meats & Fish        NaN           NaN
# 1                     NaN                   NaN   (3.5 oz)           NaN
# 2                     NaN                   NaN        NaN           NaN
# 3        Anchovies tinned              300 cals   300 cals        Medium
# 4     Bacon average fried  250 cals (2 rashers)   500 cals          High
# 5   Bacon average grilled              150 cals   380 cals      Med-High
# 6            Beef (roast)              300 cals   280 cals        Medium
# 7     Beef burgers frozen              320 cals   280 cals      Med-High
# 8                 Chicken              220 cals   200 cals        Medium
# 9                 Cockles               50 cals    50 cals           Low
# 10              Cod fresh              150 cals   100 cals   Low calorie
# 11     Cod chip shop food              400 cals   200 cals      Med-High
# ...

# %%
df[1].dropna(axis=0, how='all', inplace=True)

# Remove '(3.5 oz)' from the DataFrame
df[1].replace({'\(3.5 oz\)': ''}, regex=True, inplace=True)

# Reset index after dropping rows
df[1].reset_index(drop=True, inplace=True)

# Set proper column names
# df[1].columns = df[1].iloc[0]
df[1] = df[1].iloc[1:]

# Reset index again
df[1].reset_index(drop=True, inplace=True)

# Display the cleaned DataFrame
print(df[1])
# Out:
#                Unnamed: 0            Unnamed: 1 Unnamed: 2 per 100 grams  \
# 0                     NaN                   NaN                      NaN
# 1        Anchovies tinned              300 cals   300 cals        Medium
# 2     Bacon average fried  250 cals (2 rashers)   500 cals          High
# 3   Bacon average grilled              150 cals   380 cals      Med-High
# 4            Beef (roast)              300 cals   280 cals        Medium
# 5     Beef burgers frozen              320 cals   280 cals      Med-High
# 6                 Chicken              220 cals   200 cals        Medium
# 7                 Cockles               50 cals    50 cals           Low
# 8               Cod fresh              150 cals   100 cals   Low calorie
# 9      Cod chip shop food              400 cals   200 cals      Med-High
# 10             Crab fresh              200 cals   110 cals   low calorie
# 11             Duck roast              400 cals   430 cals          High
#
# ...

# %%
import pandas as pd

# Assuming df[1] is your DataFrame containing the bad data
# Remove '(3.5 oz)' from the DataFrame
df[1].replace({'\(3.5 oz\)': ''}, regex=True, inplace=True)

# Drop unnecessary columns and rows containing NaN values
df[1].dropna(axis=1, how='all', inplace=True)
df[1].dropna(axis=0, how='all', inplace=True)

# Reset index
df[1].reset_index(drop=True, inplace=True)

# Set proper column names
# df[1].columns = ['Food', 'Energy Content', 'Energy Content per 100 grams', 'Portion Size']

# Display the cleaned DataFrame
(df[1])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15636\610494382.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[1].replace({'\(3.5 oz\)': ''}, regex=True, inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_15636\610494382.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[1].dropna(axis=1, how='all', inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_15636\610494382.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df[1].dropna(inplace=True,how='all')
df[1]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15636\2467667112.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[1].dropna(inplace=True,how='all')
#                Unnamed: 0            Unnamed: 1 Unnamed: 2 per 100 grams
# 0                     NaN                   NaN                      NaN
# 1        Anchovies tinned              300 cals   300 cals        Medium
# 2     Bacon average fried  250 cals (2 rashers)   500 cals          High
# 3   Bacon average grilled              150 cals   380 cals      Med-High
# 4            Beef (roast)              300 cals   280 cals        Medium
# 5     Beef burgers frozen              320 cals   280 cals      Med-High
# 6                 Chicken              220 cals   200 cals        Medium
# ...

# %%
df.iloc[1:].reset_index(drop=True)
# Out:
#                Unnamed: 0            Unnamed: 1 Unnamed: 2 per 100 grams  \
# 0                     NaN                   NaN                      NaN
# 1        Anchovies tinned              300 cals   300 cals        Medium
# 2     Bacon average fried  250 cals (2 rashers)   500 cals          High
# 3   Bacon average grilled              150 cals   380 cals      Med-High
# 4            Beef (roast)              300 cals   280 cals        Medium
# 5     Beef burgers frozen              320 cals   280 cals      Med-High
# 6                 Chicken              220 cals   200 cals        Medium
# 7                 Cockles               50 cals    50 cals           Low
# 8               Cod fresh              150 cals   100 cals   Low calorie
# 9      Cod chip shop food              400 cals   200 cals      Med-High
# 10             Crab fresh              200 cals   110 cals   low calorie
# 11             Duck roast              400 cals   430 cals          High
#
# ...

# %%
df[1].dropna(axis=1, how='all')
df[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
